# %%
# %pylab inline
x=randn(10)
plot(x)
figcaption("This figure shows that \n dggyu euieui \n and last")
x=randn(10)
figure()
plot(x)
figcaption("This figure shows that \n dggyu euieui \n and last")
x=randn(10)
figure()
plot(x)
figcaption("This figure is really pretty",label="fig:test")

print("zz")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <div class=caption><b> Caption: </b> This figure shows that <br> dggyu euieui <br> and last</div>
# <div class=caption><b> Caption: </b> This figure shows that <br> dggyu euieui <br> and last</div>
# <div class=caption><b> Caption: </b> This figure is really pretty</div>
# zz

# %%
from IPython.display import HTML

# %%
display(HTML(
"""<style>
.caption {
font-weight: normal;
text-align: left;
width:60%; margin-left:10%; border:2px solid; padding-top:5px; padding-bottom:5px;
background-color:white;border-color:#efd3d7;color:black;
border-radius:8px;-webkit-border-radius:8px;-moz-border-radius:8px;border-radius:8px
}
</style>"""))

def figcaption(text,label=""):
    display(HTML("<div class=caption><b> Caption: </b> %s</div>"  % text.replace('\n','<br>')))

figcaption("This figure éèshows that \n dggyu euieui \n and last")
"This figure shows that \n dggyu euieui \n and last".replace('\n','<br>')
# Out:
# <style>
# .caption {
# font-weight: normal;
# text-align: left;
# width:60%; margin-left:10%; border:2px solid; padding-top:5px; padding-bottom:5px;
# background-color:white;border-color:#efd3d7;color:black;
# border-radius:8px;-webkit-border-radius:8px;-moz-border-radius:8px;border-radius:8px
# }
# </style>
# <div class=caption><b> Caption: </b> This figure éèshows that <br> dggyu euieui <br> and last</div>
# 'This figure shows that <br> dggyu euieui <br> and last'
